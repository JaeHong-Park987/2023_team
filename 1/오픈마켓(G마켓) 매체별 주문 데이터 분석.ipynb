# %% [markdown]
# ## 1. 데이터 둘러보기

# %%
#한글 폰트 설정하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#런타임 다시 시작
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#기본 패키지 불러오기
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.style.use('seaborn')
sns.set(font_scale=1)
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams['font.family'] = 'NanumGothic'


import warnings #경고 메세지 무시하기
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# <ipython-input-1-6d92424f4aa8>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
#구글 드라이브 마운트하기(이미 되어있다면 건너뛴다)
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 불러오기
gm = pd.read_excel('/content/drive/MyDrive/data/2023 스터디 프로젝트 데이터/오픈마켓/오픈마켓 매체별 주문 데이터.xlsx', sheet_name = 4)

# %%
gm.head(10)
# Out:
#                           Title  \
# 0       생새우살 특대 사이즈 1+1(약 40마리)
# 1         본사직영! 코웨이 직수정수기 첫 할인!
# 2  코카콜라 제로 300ml x24페트 +2021 달력
# 3      나크제이 디퓨저 500ml 크리스마스 에디션
# 4       국내산 한치 250gX6팩 / 총 12마리
# 5       [롯데렌터카]신차장기렌트+블랙박스/썬팅제공
# 6      국내생산 3D 일회용마스크 100매 무료배송
# 7    [총12입]모나리자 미용티슈 250매 3입 4팩
# 8  [20%+20%] 쉬슬러 고농축 세탁세제 2개+증정
# 9        팬틴 극손상케어 트리트먼트 6개+미니증정
#
#                                            Title_URL  \
# 0  javascript:GoSNAChannel('CHM2J040','http://ite...
# 1  javascript:GoSNAChannel('CHM2J040','http://ite...
# 2  javascript:GoSNAChannel('CHM2J040','http://ite...
# 3  javascript:GoSNAChannel('CHM2J040','http://ite...
# 4  javascript:GoSNAChannel('CHM2J040','http://ite...
# 5  javascript:GoSNAChannel('CHM2J040','http://ite...
# 6  javascript:GoSNAChannel('CHM2J040','http://ite...
# 7  javascript:GoSNAChannel('CHM2J040','http://ite...
# 8  javascript:GoSNAChannel('CHM2J040','http://ite...
# 9  javascript:GoSNAChannel('CHM2J040','http://ite...
#
#                                                Image  \
# 0  http://image.gmarket.co.kr/service_image/2020/...
# 1  http://image.gmarket.co.kr/service_image/2020/...
# 2  http://image.gmarket.co.kr/service_image/2020/...
# 3  http://image.gmarket.co.kr/service_image/2020/...
# 4  http://image.gmarket.co.kr/hanbando/202012/8d6...
# 5  http://image.gmarket.co.kr/service_image/2020/...
# 6  http://image.gmarket.co.kr/service_image/2020/...
# 7  http://image.gmarket.co.kr/service_image/2020/...
# 8  http://image.gmarket.co.kr/service_image/2020/...
# 9  http://image.gmarket.co.kr/service_image/2020/...
#
#                                             Shop_URL                     Shop  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2  javascript:GoSNAChannel('CHM2J043','http://rpp...  코카콜라 브랜드위크 12% 중복할인쿠폰받기
# 3                                                NaN                      NaN
# 4  javascript:GoSNAChannel('CHM2J043','http://rpp...         공영쇼핑TV 9% 중복쿠폰받기
# 5                                                NaN                      NaN
# 6                                                NaN                      NaN
# 7  javascript:GoSNAChannel('CHM2J043','http://rpp...       모나지라  20% 중복쿠폰쿠폰받기
# 8  javascript:GoSNAChannel('CHM2J043','http://rpp...       아토세이프 중복쿠폰 20%쿠폰받기
# 9  javascript:GoSNAChannel('CHM2J043','http://rpp...           팬틴 20%중복쿠폰쿠폰받기
#
#                                            Shop_URL1  sale sale2     Price  \
# 0                                                NaN  16.0    할인   10,900원
# 1                                                NaN   NaN   NaN   20,900원
# 2                                                NaN   2.0    할인   20,580원
# 3                                                NaN  61.0    할인    8,900원
# 4  javascript:GoSNAChannel('CHM2J042','http://min...   NaN   NaN   49,900원
# 5                                                NaN   NaN   NaN  195,792원
# 6                                                NaN   9.0    할인    9,900원
# 7  http://shop.gmarket.co.kr/SmartDelivery/SmartD...   NaN   NaN   18,900원
# 8  http://shop.gmarket.co.kr/SmartDelivery/SmartD...  11.0    할인   15,900원
# 9  http://shop.gmarket.co.kr/SmartDelivery/SmartD...  48.0    할인   25,840원
#
#     Price3         Tag  Tag4        buy     Shop5 Shop6  \
# 0  13,000원  최대 2.3% 적립  무료배송  1,007\n구매       NaN   NaN
# 1      NaN         NaN   NaN  1,786\n구매       NaN   NaN
# 2  21,000원  최대 2.3% 적립  무료배송  2,019\n구매  12% 중복할인  쿠폰받기
# 3  23,000원  최대 2.3% 적립  무료배송    1만+\n구매       NaN   NaN
# 4      NaN  최대 2.3% 적립  무료배송      3\n구매     9% 중복  쿠폰받기
# 5      NaN         NaN   NaN    528\n구매       NaN   NaN
# 6  10,900원  최대 2.3% 적립  무료배송    4만+\n구매       NaN   NaN
# 7      NaN    최대 3% 적립  무료배송    5만+\n구매  20% 중복쿠폰  쿠폰받기
# 8  17,900원    최대 3% 적립  무료배송  9,116\n구매  중복쿠폰 20%  쿠폰받기
# 9  50,650원    최대 3% 적립  무료배송  8,074\n구매   20%중복쿠폰  쿠폰받기
#
#               Current_Time
# 0  2020-12-16 18:03:23.897
# 1  2020-12-16 18:03:23.993
# 2  2020-12-16 18:03:24.060
# 3  2020-12-16 18:03:24.113
# 4  2020-12-16 18:03:24.200
# 5  2020-12-16 18:03:24.260
# 6  2020-12-16 18:03:24.337
# 7  2020-12-16 18:03:24.399
# 8  2020-12-16 18:03:24.462
# 9  2020-12-16 18:03:24.528

# %%
# 컬럼 기본 정보 확인하기
gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         292 non-null    object
#  1   Title_URL     292 non-null    object
#  2   Image         292 non-null    object
#  3   Shop_URL      169 non-null    object
#  4   Shop          169 non-null    object
#  5   Shop_URL1     121 non-null    object
#  6   sale          221 non-null    float64
#  7   sale2         221 non-null    object
#  8   Price         292 non-null    object
#  9   Price3        221 non-null    object
#  10  Tag           281 non-null    object
#  11  Tag4          247 non-null    object
#  12  buy           286 non-null    object
#  13  Shop5         169 non-null    object
#  14  Shop6         169 non-null    object
#  15  Current_Time  292 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 36.6+ KB

# %%
# 연속형 데이터의 통계치 확인
gm.describe()
# Out:
#              sale
# count  221.000000
# mean    32.325792
# std     23.007760
# min      1.000000
# 25%     11.000000
# 50%     27.000000
# 75%     50.000000
# max     70.000000

# %%
# 범주형 데이터의 통계치 확인하기
gm.describe(include = np.object_)
# Out:
#                           Title  \
# count                       292
# unique                      292
# top     생새우살 특대 사이즈 1+1(약 40마리)
# freq                          1
#
#                                                 Title_URL  \
# count                                                 292
# unique                                                292
# top     javascript:GoSNAChannel('CHM2J040','http://ite...
# freq                                                    1
#
#                                                     Image  \
# count                                                 292
# unique                                                292
# top     http://image.gmarket.co.kr/service_image/2020/...
# freq                                                    1
#
#                                                  Shop_URL                Shop  \
# count                                                 169                 169
# unique                                                 64                 101
# top     javascript:GoSNAChannel('CHM2J043','http://cor...  스마일클럽은 매일 무료배송쿠폰받기
# freq                                                   31                  20
#
#                                                 Shop_URL1 sale2    Price  \
# count                                                 121   221      292
# unique                                                 29     1      189
# top     http://shop.gmarket.co.kr/SmartDelivery/SmartD...    할인  19,900원
# freq                                                   79   221       10
#
#          Price3         Tag  Tag4      buy    Shop5 Shop6  \
# count       221         281   247      286      169   169
# unique      168           3     1      225       71     1
# top     30,000원  최대 2.3% 적립  무료배송  1만+\n구매  매일 무료배송  쿠폰받기
# freq          6         201   247       22       31   169
#
#                    Current_Time
# count                       292
# unique                      292
# top     2020-12-16 18:03:23.897
# freq                          1

# %%
# 범주형 데이터 컬럼 속 내용 확인
print('Shop_URL: ', gm['Shop_URL'].unique())
print('Shop: ', gm['Shop'].unique())
print('Shop_URL1: ', gm['Shop_URL1'].unique())
print('Tag: ', gm['Tag'].unique())
print('Shop5: ', gm['Shop5'].unique())
# Out:
# Shop_URL:  [nan
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43199', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=31986', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42867', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40564', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43197', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41288', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40555', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=31868', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43341', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=37378', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43156', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40679', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://corners.gmarket.co.kr/SmileClub?type=coupon#anchor__coupon--smiledelivery', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43243', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41181', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42203', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43198', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42996', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40337', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41367', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=35971', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=37361', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40854', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=35329', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40083', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40764', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=35338', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42424', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=34279', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40953', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42897', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43373', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42778', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=34344', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41501', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=37431', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42800', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43247', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40818', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43376', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36307', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36146', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=34392', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41183', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40770', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=33142', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=38004', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41410', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40761', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41579', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40875', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=41521', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36985', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42134', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42703', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36671', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=43224', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=30132', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36079', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40553', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=36886', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=40369', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=37881', '');"
#  "javascript:GoSNAChannel('CHM2J043','http://rpp.gmarket.co.kr/?exhib=42846', '');"]
# Shop:  [nan '코카콜라 브랜드위크 12% 중복할인쿠폰받기' '공영쇼핑TV 9% 중복쿠폰받기' '모나지라  20% 중복쿠폰쿠폰받기'
#  '아토세이프 중복쿠폰 20%쿠폰받기' '팬틴 20%중복쿠폰쿠폰받기' '스마일배송 연말결산  20%+7% 중복쿠폰쿠폰받기'
#  '동원 연말결산  12% 중복쿠폰쿠폰받기' '푸드데이 15%추가할인쿠폰받기' '푸드데이  15% 쿠폰쿠폰받기'
#  'NS홈쇼핑 9% 중복쿠폰!쿠폰받기' 'SK스토아 DAY 단 하루 최대 37% 할인쿠폰받기'
#  '피스넷 크리스마스 중복쿠폰5%쿠폰받기' '15% 쿠폰 (스마일클럽)쿠폰받기' '12월백화점연합 7% 할인쿠폰받기'
#  '홀리데이 스타일 25%쿠폰쿠폰받기' '스마일클럽은 매일 무료배송쿠폰받기' '주방대전 스마일클럽  15% 중복쿠폰쿠폰받기'
#  '애경 스마일배송 연말결산쿠폰받기' '아모레 연말결산 20%+15% 중복쿠폰쿠폰받기' '헨켈홈케어  중복 15%쿠폰받기'
#  '에너자이저 17% 중복쿠폰쿠폰받기' '대상  17%중복쿠폰쿠폰받기' '수요일은 푸드데이  15% 중복할인쿠폰받기'
#  '푸드데이  15% 중복쿠폰쿠폰받기' '스마일클럽은  매일 무료배송쿠폰받기' '바쏘 27% 중복쿠폰 쿠폰받기'
#  '홀리데이 스타일 25%쿠폰+10%카드사할인쿠폰받기' '보솜이 최대 4500원 중복쿠폰쿠폰받기' 'LG생활건강 17% 쿠폰쿠폰받기'
#  '오랄비  20%중복쿠폰쿠폰받기' '유한킴벌리 17%쿠폰쿠폰받기' '이달의할인 10% 중복쿠폰쿠폰받기'
#  '페이퍼플레인 22%쿠폰받기쿠폰받기' '롯데칠성  12%중복쿠폰쿠폰받기' '스마일클럽 이달의 할인  10% 중복쿠폰쿠폰받기'
#  '애플스토어 10% 중복쿠폰쿠폰받기' '네파  20% 중복쿠폰쿠폰받기' '6대백화점 7% 중복쿠폰받기'
#  '롯데백화점잠실점단독세일 8% 할인쿠폰받기' 'SK스토아 최대 37% 할인쿠폰받기' '공영쇼핑TV 중복 9%할인쿠폰받기'
#  '홀리데이   스타일25%쿠폰쿠폰받기' '크리니크 10% 중복쿠폰쿠폰받기' '신세계아울렛 최대 20% 중복쿠폰받기'
#  '녹십자 10%  스마일배송 중복쿠폰쿠폰받기' '탄력피부! AHC  20%중복쿠폰쿠폰받기'
#  '오리온 이달의 할인 10%중복할인쿠폰받기' '미샤데이 최대 25% 중복쿠폰쿠폰받기' '3M  33%추가할인쿠폰받기'
#  '안마의자 20%추가할인쿠폰받기' '[인켈TV]집콕세일 스마일클럽 7%쿠폰받기' '가격호러쇼 히츠 10% 중복할인쿠폰받기'
#  '홀리데이 스타일25%쿠폰쿠폰받기' 'NC백화점단독전 최대 15%쿠폰받기' '아시아나항공 스마일페이 국내선 5% 할인쿠폰받기'
#  '[캘빈클라인]홀리데이 스타일 이번주만 25%쿠폰!쿠폰받기' 'K쇼핑 DAY 단하루 최대 37% 할인쿠폰받기'
#  '온에어 스페셜딜  30% 할인쿠폰쿠폰받기' '연말결산★제이준 스마일배송 최대 20%중복쿠폰쿠폰받기'
#  '남양 브랜드위크 10% 중복할인쿠폰받기' '콜핑  20% 중복쿠폰쿠폰받기' '농심 스마일배송 연말결산쿠폰받기'
#  '남양 스마일 연말결산 10% 중복할인쿠폰받기' '풀무원  15%중복쿠폰쿠폰받기' '스마일클럽 고객은 5% 추가할인쿠폰받기'
#  '맥널티 스마일배송  10%, 12% 중복쿠폰쿠폰받기' '원더브라 15%중복쿠폰쿠폰받기'
#  '패션쿠폰북 지오다노/컨셉원 최대 22%중복쿠폰쿠폰받기' '스마일 연말결산 20% 할인쿠폰받기' '대상 17%중복쿠폰쿠폰받기'
#  '해태제과 중복 10%쿠폰받기' '아모레 연말결산 20%+17% 중복쿠폰쿠폰받기' '남양유업 분유  5천원 중복쿠폰쿠폰받기'
#  '스포츠브랜드 휠라 20중복 쿠폰쿠폰받기' '백화점연합 최대7% 중복쿠폰받기' '피앤지  20%중복쿠폰쿠폰받기'
#  '에버라스트 22%중복쿠폰쿠폰받기' '해태 브랜드위크 10% 중복할인쿠폰받기' '동원F/B  1000원 중복쿠폰쿠폰받기'
#  'LG생활건강 22% 깜짝쿠폰쿠폰받기' '크리오 15% 한번 더 할인!쿠폰받기' '크래프트하인즈 브랜드위크 10% 중복할인쿠폰받기'
#  '무궁화  10%중복쿠폰쿠폰받기' '록시땅 온에어 스페셜 30% 할인쿠폰쿠폰받기'
#  '롯데푸드 연말결산  20%+추가 12% 쿠폰쿠폰받기' '그랜드 조선 제주 21.01.08 OPEN 기념 카드 할인쿠폰받기'
#  '홀리데이 스타일  25%쿠폰쿠폰받기' '스마일클럽 매일 3천원 장보기 할인쿠폰받기' '킨도 4천원 중복 쿠폰쿠폰받기'
#  '모나리자  20% 중복쿠폰쿠폰받기' '피앤지 20%중복쿠폰쿠폰받기' '까스텔바작 20%중복쿠폰쿠폰받기'
#  '자연의품격 연말결산 12% 중복쿠폰쿠폰받기' '홀리데이  스타일25%쿠폰쿠폰받기'
#  '롯데헬스원 연말결산 추가  20%+20% 쿠폰쿠폰받기' '긴급보습 에스트라 입점 첫SALE 중복15%쿠폰받기'
#  '켈로그 연말결산 20% 깜짝쿠폰쿠폰받기' '웅진 스마일 연말결산 15% 중복할인쿠폰받기' '아모레퍼시픽 17% 중복쿠폰쿠폰받기'
#  '연말결산★라벨영 스마일배송 최대 15%중복쿠폰쿠폰받기' '연말결산★라벨영 스마일배송  최대 15%중복쿠폰쿠폰받기']
# Shop_URL1:  [nan
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/gongyoungtv', '');"
#  'http://shop.gmarket.co.kr/SmartDelivery/SmartDelivery.aspx'
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/nsmalltv', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/skstoa', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/lotteec', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/iparkmall', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/tefalmall', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/innisfree', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/galleria6', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/LFmallG', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/leecomnepa', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/hdepart01', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/lottedep1', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://mobile.gmarket.co.kr/SellerShop/ssgoutlets', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/missha', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/lecreusetkorea', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/faple', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/NCDEPARTMENTSTORE', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/kthshop', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/kolpingmll', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/akplaza1', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/giordano', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/filakorea1', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/debec', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/jomakorea2', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/hmallcom', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/shinsegae9', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://corners.gmarket.co.kr/ExpressShop/Home?SellerId=lottesuper', '');"
#  "javascript:GoSNAChannel('CHM2J042','http://minishop.gmarket.co.kr/castelbajac', '');"]
# Tag:  ['최대 2.3% 적립' nan '최대 3% 적립' 'TAX/유류세포함']
# Shop5:  [nan '12% 중복할인' '9% 중복' '20% 중복쿠폰' '중복쿠폰 20%' '20%중복쿠폰' '20%+7% 중복쿠폰'
#  '12% 중복쿠폰' '15%추가할인' '15% 쿠폰' '9% 중복쿠폰!' '최대 37% 할인' '중복쿠폰5%' '(스마일클럽)'
#  '7% 할인' '25%쿠폰' '매일 무료배송' '15% 중복쿠폰' '스마일배송 연말결산' '20%+15% 중복쿠폰' '중복 15%'
#  '17% 중복쿠폰' '17%중복쿠폰' '15% 중복할인' '27% 중복쿠폰' '25%쿠폰+10%카드사할인'
#  '최대 4500원 중복쿠폰' '17% 쿠폰' '17%쿠폰' '10% 중복쿠폰' '22%쿠폰받기' '12%중복쿠폰' '7% 중복'
#  '8% 할인' '중복 9%할인' '스타일25%쿠폰' '최대 20% 중복' '스마일배송 중복쿠폰' '10%중복할인'
#  '최대 25% 중복쿠폰' '연말결산' '33%추가할인' '20%추가할인' '스마일클럽 7%' '10% 중복할인' '최대 15%'
#  '국내선 5% 할인' '이번주만 25%쿠폰!' '30% 할인쿠폰' '최대 20%중복쿠폰' '15%중복쿠폰' '5% 추가할인'
#  '10%, 12% 중복쿠폰' '22%중복쿠폰' '20% 할인' '중복 10%' '20%+17% 중복쿠폰' '5천원 중복쿠폰'
#  '20중복 쿠폰' '최대7% 중복' '1000원 중복쿠폰' '22% 깜짝쿠폰' '15% 한번 더 할인!' '10%중복쿠폰'
#  '20%+추가 12% 쿠폰' 'OPEN 기념 카드 할인' '매일 3천원 장보기 할인' '4천원 중복 쿠폰' '20%+20% 쿠폰'
#  '첫SALE 중복15%' '20% 깜짝쿠폰' '최대 15%중복쿠폰']

# %%
# 데이터 내용 간단히 정리
print('총 데이터 수 : ', gm.shape[0] * gm.shape[1])
print('총 결측치 수 : {} = 전체 데이터의 {:.2f}%'.format(gm.isnull().sum().sum(), (gm.isnull().sum().sum() * 100) / (gm.shape[0] * gm.shape[1])))
print('G마켓-슈퍼딜 첫 페이지 상품 수 : ', gm['Title'].nunique())
print('제공한 쿠폰 상세 페이지 수: ', gm['Shop_URL'].nunique())
# Out:
# 총 데이터 수 :  4672
# 총 결측치 수 : 938 = 전체 데이터의 20.08%
# G마켓-슈퍼딜 첫 페이지 상품 수 :  292
# 제공한 쿠폰 상세 페이지 수:  64

# %% [markdown]
# ## 2. 데이터 정비하기

# %% [markdown]
# ### 2-1 결측치 처리하기

# %%
gm.isnull().any(axis = 0)
# Out:
# Title           False
# Title_URL       False
# Image           False
# Shop_URL         True
# Shop             True
# Shop_URL1        True
# sale             True
# sale2            True
# Price           False
# Price3           True
# Tag              True
# Tag4             True
# buy              True
# Shop5            True
# Shop6            True
# Current_Time    False
# dtype: bool

# %%
gm.isnull().sum()
# Out:
# Title             0
# Title_URL         0
# Image             0
# Shop_URL        123
# Shop            123
# Shop_URL1       171
# sale             71
# sale2            71
# Price             0
# Price3           71
# Tag              11
# Tag4             45
# buy               6
# Shop5           123
# Shop6           123
# Current_Time      0
# dtype: int64

# %%
gm['sale'].fillna(0, inplace = True)
gm['Shop6'].fillna('쿠폰받기x', inplace = True)
gm.head()
# Out:
#                           Title  \
# 0       생새우살 특대 사이즈 1+1(약 40마리)
# 1         본사직영! 코웨이 직수정수기 첫 할인!
# 2  코카콜라 제로 300ml x24페트 +2021 달력
# 3      나크제이 디퓨저 500ml 크리스마스 에디션
# 4       국내산 한치 250gX6팩 / 총 12마리
#
#                                            Title_URL  \
# 0  javascript:GoSNAChannel('CHM2J040','http://ite...
# 1  javascript:GoSNAChannel('CHM2J040','http://ite...
# 2  javascript:GoSNAChannel('CHM2J040','http://ite...
# 3  javascript:GoSNAChannel('CHM2J040','http://ite...
# 4  javascript:GoSNAChannel('CHM2J040','http://ite...
#
#                                                Image  \
# 0  http://image.gmarket.co.kr/service_image/2020/...
# 1  http://image.gmarket.co.kr/service_image/2020/...
# 2  http://image.gmarket.co.kr/service_image/2020/...
# 3  http://image.gmarket.co.kr/service_image/2020/...
# 4  http://image.gmarket.co.kr/hanbando/202012/8d6...
#
#                                             Shop_URL                     Shop  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2  javascript:GoSNAChannel('CHM2J043','http://rpp...  코카콜라 브랜드위크 12% 중복할인쿠폰받기
# 3                                                NaN                      NaN
# 4  javascript:GoSNAChannel('CHM2J043','http://rpp...         공영쇼핑TV 9% 중복쿠폰받기
#
#                                            Shop_URL1  sale sale2    Price  \
# 0                                                NaN  16.0    할인  10,900원
# 1                                                NaN   0.0   NaN  20,900원
# 2                                                NaN   2.0    할인  20,580원
# 3                                                NaN  61.0    할인   8,900원
# 4  javascript:GoSNAChannel('CHM2J042','http://min...   0.0   NaN  49,900원
#
#     Price3         Tag  Tag4        buy     Shop5  Shop6  \
# 0  13,000원  최대 2.3% 적립  무료배송  1,007\n구매       NaN  쿠폰받기x
# 1      NaN         NaN   NaN  1,786\n구매       NaN  쿠폰받기x
# 2  21,000원  최대 2.3% 적립  무료배송  2,019\n구매  12% 중복할인   쿠폰받기
# 3  23,000원  최대 2.3% 적립  무료배송    1만+\n구매       NaN  쿠폰받기x
# 4      NaN  최대 2.3% 적립  무료배송      3\n구매     9% 중복   쿠폰받기
#
#               Current_Time
# 0  2020-12-16 18:03:23.897
# 1  2020-12-16 18:03:23.993
# 2  2020-12-16 18:03:24.060
# 3  2020-12-16 18:03:24.113
# 4  2020-12-16 18:03:24.200

# %% [markdown]
# ## 3. EDA & Visualization

# %% [markdown]
# ### 3-1. 쿠폰을 받을 수 있는 상품 비율은?

# %%
gm['Shop6'].value_counts()
# Out:
# 쿠폰받기     169
# 쿠폰받기x    123
# Name: Shop6, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 8))

gm['Shop6'].value_counts().plot.pie(ax = ax[0], autopct = '%1.0f%%', shadow = True)
ax[0].set_title('쿠폰받기 가능 여부 비율', size = 18)
ax[0].set_ylabel('')

sns.countplot(data = gm, y = 'Shop6', order = ['쿠폰받기', '쿠폰받기x'], ax = ax[1])
ax[1].set_title('쿠폰받기 가능 여부 수', size = 18)
# Out:
# Text(0.5, 1.0, '쿠폰받기 가능 여부 수')

# %% [markdown]
# ### 3-2. 쿠폰 유무에 따른 할인율 분포

# %%
gm['sale'].describe()
# Out:
# count    292.000000
# mean      24.465753
# std       24.354954
# min        0.000000
# 25%        1.000000
# 50%       15.000000
# 75%       50.000000
# max       70.000000
# Name: sale, dtype: float64

# %%
print(gm.skew())
print(gm.kurt())
# Out:
# sale    0.668821
# dtype: float64
# sale   -1.030161
# dtype: float64

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))

sns.histplot(gm[gm['Shop6'] == '쿠폰받기']['sale'], ax = ax[0])
sns.histplot(gm[gm['Shop6'] == '쿠폰받기x']['sale'], ax = ax[0])
ax[0].legend(['쿠폰받기', '쿠폰받기x'])

sns.kdeplot(gm[gm['Shop6'] == '쿠폰받기']['sale'], ax = ax[1])
sns.kdeplot(gm[gm['Shop6'] == '쿠폰받기x']['sale'], ax = ax[1])
ax[1].legend(['쿠폰받기', '쿠폰받기x'])

plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 2-3. 가장 비싼 제품과 가장 싼 제품은?
